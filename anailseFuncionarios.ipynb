# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoHHoffmann/analise-funcionarios/blob/main/anailseFuncionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analisando o dataset employees.csv

# %%
import pandas as pd
df = pd.read_csv('/content/employees.csv')
df.head()
# Out:
#    ID            Nome  Idade                Cargo  Salário Data_Admissão  \
# 0   1       Ana Silva     34    Analista de Dados     7500    2018-03-15
# 1   2     Carlos Lima     29   Cientista de Dados    10500    2020-07-10
# 2   3   Beatriz Souza     41  Gerente de Projetos    15000    2015-11-25
# 3   4     João Mendes     38        Desenvolvedor     8200    2017-09-08
# 4   5  Fernanda Rocha     26          UX Designer     6700    2021-05-14
#
#   Departamento
# 0           TI
# 1           TI
# 2       Gestão
# 3           TI
# 4       Design

# %% [markdown]
# ## Selecionando apenas os funcionarios que trabalham com TI.

# %%
dep_ti = df[df['Departamento'] == 'TI']
dep_ti
# Out:
#     ID              Nome  Idade                    Cargo  Salário  \
# 0    1         Ana Silva     34        Analista de Dados     7500
# 1    2       Carlos Lima     29       Cientista de Dados    10500
# 3    4       João Mendes     38            Desenvolvedor     8200
# 5    6    Marcos Andrade     32   Engenheiro de Software    11500
# 6    7     Luciana Alves     30                      DBA     9800
# 10  11   Vanessa Martins     45    Arquiteto de Software    14500
# 11  12    Thiago Ribeiro     31            Desenvolvedor     8600
# 13  14   Fernando Duarte     39     Analista de Sistemas     9100
# 15  16     Eduardo Gomes     35  Desenvolvedor Front-End    10200
# 16  17  Carolina Ribeiro     33   Desenvolvedor Back-End    10700
#
#    Data_Admissão Departamento
# 0     2018-03-15           TI
# 1     2020-07-10           TI
# 3     2017-09-08           TI
# 5     2019-02-21           TI
# 6     2022-06-30           TI
# 10    2014-08-15           TI
# 11    2019-10-23           TI
# 13    2016-07-18           TI
# 15    2018-09-17           TI
# 16    2019-12-05           TI

# %% [markdown]
# ## Encontrando a média salarial dos funcionarios

# %%
media_salario = df['Salário'].mean()
print(f'A media salarial dessa empresa é de {media_salario:.2f}')
# Out:
# A media salarial dessa empresa é de 11540.00

# %% [markdown]
# ## Filtrando os funcionarios que foram admitidos apos 2019

# %%
df['Data_Admissão'] = pd.to_datetime(df['Data_Admissão'])
admitidos_apos_2019 = df[df['Data_Admissão'].dt.year > 2019]
admitidos_apos_2019
# Out:
#     ID            Nome  Idade               Cargo  Salário Data_Admissão  \
# 1    2     Carlos Lima     29  Cientista de Dados    10500    2020-07-10
# 4    5  Fernanda Rocha     26         UX Designer     6700    2021-05-14
# 6    7   Luciana Alves     30                 DBA     9800    2022-06-30
# 14  15   Juliana Rocha     28      Analista de UX     7500    2020-03-22
#
#    Departamento
# 1            TI
# 4        Design
# 6            TI
# 14       Design

# %% [markdown]
# ## Criando nova coluna que representa o tempo que o funcionario esta na empresa em anos

# %%
df['Tempo_Empresa'] = (pd.Timestamp.now() - pd.to_datetime(df['Data_Admissão'])).dt.days // 365
df
# Out:
#     ID              Nome  Idade                    Cargo  Salário  \
# 0    1         Ana Silva     34        Analista de Dados     7500
# 1    2       Carlos Lima     29       Cientista de Dados    10500
# 2    3     Beatriz Souza     41      Gerente de Projetos    15000
# 3    4       João Mendes     38            Desenvolvedor     8200
# 4    5    Fernanda Rocha     26              UX Designer     6700
# 5    6    Marcos Andrade     32   Engenheiro de Software    11500
# 6    7     Luciana Alves     30                      DBA     9800
# 7    8     Ricardo Pinto     40    Analista de Segurança     8700
# 8    9    Gabriela Costa     27           Analista de BI     9200
# 9   10    Paulo Oliveira     36             Scrum Master    10800
# 10  11   Vanessa Martins     45    Arquiteto de Software    14500
# 11  12    Thiago Ribeiro     31            Desenvolvedor     8600
# 12  13    Patrícia Nunes     29            Gerente de TI    15800
# 13  14   Fernando Duarte     39     Analista de Sistemas     9100
# 14  15     Juliana Rocha     28           Analista de UX     7500
# 15  16     Eduardo Gomes     35  Desenvolvedor Front-End    10200
# 16  17  Carolina Ribeiro     33   Desenvolvedor Back-End    10700
# 17  18     Rodrigo Alves     37         Gerente de Infra    16500
# 18  19    Mônica Cardoso     42            Diretor de TI    18000
# 19  20     Gustavo Lopes     50                      CTO    22000
#
#    Data_Admissão Departamento  Tempo_Empresa
# 0     2018-03-15           TI              7
# 1     2020-07-10           TI              4
# 2     2015-11-25       Gestão              9
# 3     2017-09-08           TI              7
# 4     2021-05-14       Design              3
# 5     2019-02-21           TI              6
# 6     2022-06-30           TI              2
# 7     2016-04-10    Segurança              8
# 8     2018-12-12           BI              6
# 9     2017-11-05       Gestão              7
# 10    2014-08-15           TI             10
# 11    2019-10-23           TI              5
# 12    2013-06-30       Gestão             11
# 13    2016-07-18           TI              8
# 14    2020-03-22       Design              5
# 15    2018-09-17           TI              6
# 16    2019-12-05           TI              5
# 17    2015-05-20        Infra              9
# 18    2012-03-10       Gestão             13
# 19    2010-01-05       Gestão             15

# %% [markdown]
# ## Filtrando o funcionario mais velho e o mais novo

# %%
mais_velho = df[df['Tempo_Empresa'] == df['Tempo_Empresa'].max()]
mais_novo = df[df['Tempo_Empresa'] == df['Tempo_Empresa'].min()]
print('Funcionario mais velho: ')
display(mais_velho)
print('Funcionario mais novo: ')
display(mais_novo)
# Out:
# Funcionario mais velho:
#     ID           Nome  Idade Cargo  Salário Data_Admissão Departamento  \
# 19  20  Gustavo Lopes     50   CTO    22000    2010-01-05       Gestão
#
#     Tempo_Empresa
# 19             15
# Funcionario mais novo:
#    ID           Nome  Idade Cargo  Salário Data_Admissão Departamento  \
# 6   7  Luciana Alves     30   DBA     9800    2022-06-30           TI
#
#    Tempo_Empresa
# 6              2

# %% [markdown]
# ## Filtrando o cargo com o maior salario medio

# %%
cargo_maior_salario = df.groupby('Cargo')['Salário'].mean().idxmax()
maior_salario_medio = df.groupby('Cargo')['Salário'].mean().max()
print(f'O cargo com o maior salario medio é: {cargo_maior_salario}, com o valor de {maior_salario_medio:.2f}')
# Out:
# O cargo com o maior salario medio é: CTO, com o valor de 22000.00

# %% [markdown]
# ## Agrupando os funcionarios por departamento e encontrando a media salarial de cada um dos departamentos

# %%
salario_medio = df.groupby('Departamento')['Salário'].mean()
display(salario_medio)
# Out:
# Departamento
# BI            9200.0
# Design        7100.0
# Gestão       16320.0
# Infra        16500.0
# Segurança     8700.0
# TI           10060.0
# Name: Salário, dtype: float64

# %% [markdown]
# ## Ordenando os funcionarios pelo tempo de empresa em ordem decrescente

# %%
tempo_empresa = df.sort_values(by='Tempo_Empresa', ascending=False)
display(tempo_empresa)
# Out:
#     ID              Nome  Idade                    Cargo  Salário  \
# 19  20     Gustavo Lopes     50                      CTO    22000
# 18  19    Mônica Cardoso     42            Diretor de TI    18000
# 12  13    Patrícia Nunes     29            Gerente de TI    15800
# 10  11   Vanessa Martins     45    Arquiteto de Software    14500
# 17  18     Rodrigo Alves     37         Gerente de Infra    16500
# 2    3     Beatriz Souza     41      Gerente de Projetos    15000
# 13  14   Fernando Duarte     39     Analista de Sistemas     9100
# 7    8     Ricardo Pinto     40    Analista de Segurança     8700
# 0    1         Ana Silva     34        Analista de Dados     7500
# 3    4       João Mendes     38            Desenvolvedor     8200
# 9   10    Paulo Oliveira     36             Scrum Master    10800
# 5    6    Marcos Andrade     32   Engenheiro de Software    11500
# 8    9    Gabriela Costa     27           Analista de BI     9200
# 15  16     Eduardo Gomes     35  Desenvolvedor Front-End    10200
# 14  15     Juliana Rocha     28           Analista de UX     7500
# 11  12    Thiago Ribeiro     31            Desenvolvedor     8600
# 16  17  Carolina Ribeiro     33   Desenvolvedor Back-End    10700
# 1    2       Carlos Lima     29       Cientista de Dados    10500
# 4    5    Fernanda Rocha     26              UX Designer     6700
# 6    7     Luciana Alves     30                      DBA     9800
#
#    Data_Admissão Departamento  Tempo_Empresa
# 19    2010-01-05       Gestão             15
# 18    2012-03-10       Gestão             13
# 12    2013-06-30       Gestão             11
# 10    2014-08-15           TI             10
# 17    2015-05-20        Infra              9
# 2     2015-11-25       Gestão              9
# 13    2016-07-18           TI              8
# 7     2016-04-10    Segurança              8
# 0     2018-03-15           TI              7
# 3     2017-09-08           TI              7
# 9     2017-11-05       Gestão              7
# 5     2019-02-21           TI              6
# 8     2018-12-12           BI              6
# 15    2018-09-17           TI              6
# 14    2020-03-22       Design              5
# 11    2019-10-23           TI              5
# 16    2019-12-05           TI              5
# 1     2020-07-10           TI              4
# 4     2021-05-14       Design              3
# 6     2022-06-30           TI              2
